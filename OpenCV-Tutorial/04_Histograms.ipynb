# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Create-gray-scale-histogram" data-toc-modified-id="Create-gray-scale-histogram-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Create gray-scale histogram</a></span></li><li><span><a href="#Create-color-histogram" data-toc-modified-id="Create-color-histogram-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create color histogram</a></span></li><li><span><a href="#Histogram-equalization" data-toc-modified-id="Histogram-equalization-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Histogram equalization</a></span></li></ul></div>

# %% [markdown]
# # Histograms

# %%
import matplotlib.pyplot as plt
import cv2

b, g, r = cv2.split(cv2.imread('beach.png'))
image = cv2.merge([r, g, b])
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

images = [image, gray_image]
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 9), squeeze=True)

for img, ax in zip(images, axs):
    ax.imshow(img, cmap='gray')
    ax.axis('off')
plt.show()

# %%
mask = None
histSize = [256]
pixel_range = [0, 256]
colors = ('r','g','b')

# %% [markdown]
# ## Create gray-scale histogram

# %%
hist = cv2.calcHist([gray_image], [0], mask, histSize, pixel_range)

plt.plot(hist)
plt.xlabel('Pixel value')
plt.ylabel('number of pixels')
plt.show()

# %% [markdown]
# ## Create color histogram

# %%
channels = cv2.split(image)

for channel, color in zip(channels, colors):
    hist = cv2.calcHist([channel], [0], mask, histSize, pixel_range)
    plt.plot(hist, color=color)
    
plt.xlabel('Pixel value')
plt.ylabel('number of pixels')
plt.show()

# %% [markdown]
# ## Histogram equalization
# - Improving the contrast of an image by stretching the distribution of pixels
# - Applied to greyscale images

# %%
equalized = cv2.equalizeHist(gray_image)

plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()
